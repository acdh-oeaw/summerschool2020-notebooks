# %%
# !pip install rdflib SPARQLWrapper ipyleaflet

# %% [markdown]
# ### In this Lesson
# * Use Wikidata SPARQL endpoint to retriev long/lat for places
# * Use HistoGIS Rest endpoint to retrieve administrative divisions of this long/lat
# * Use Lobid/GND to enrich MPR Data

# %% [markdown]
# #### Lets start of with (the beginning) of an ÖBL-Biography
#
# *Kob, Anton* - https://apis.acdh.oeaw.ac.at/person/70582
#
# Arbeitete zuerst als Müllergeselle bei seinem Vater. Nach erster Lehrzeit beim Vergolder A. Hanny in Kaltern, zog er 1852 nach München und von dort als Vergoldergehilfe nach Augsburg, kehrte aber noch im selben Jahre zurück und nahm von nun an Unterricht bei Joh. Bapt. Pendl, dessen Schwiegersohn er später wurde. 1859 übersiedelte er nach Gries b. Bozen und 1863 nach Bozen.

# %%
bio = "Arbeitete zuerst als Müllergeselle bei seinem Vater. Nach erster Lehrzeit beim Vergolder A. Hanny in Kaltern, zog er 1852 nach München und von dort als Vergoldergehilfe nach Augsburg, kehrte aber noch im selben Jahre zurück und nahm von nun an Unterricht bei Joh. Bapt. Pendl, dessen Schwiegersohn er später wurde. 1859 übersiedelte er nach Gries b. Bozen und 1863 nach Bozen."

# %% [markdown]
# #### And now we use the Regex of yesterdays NLP session to extract PlaceNames and Years

# %%
import re
year_place = []
for year in re.finditer(r'([\d\–]{2,7}).*?\snach\s.*?([A-Z]\w+)', bio):
    print('year: {} / place: {}'.format(year.group(1), year.group(2)))
    year_place.append((year.group(1), year.group(2)))
year_place
# Out:
# year: 1852 / place: München
# year: 1859 / place: Gries
# year: 1863 / place: Bozen
# [('1852', 'München'), ('1859', 'Gries'), ('1863', 'Bozen')]

# %%
from IPython.display import Image
from IPython.core.display import HTML

# %%
import sys
from rdflib import Graph,URIRef
import pandas as pd
pd.set_option("display.width",100)
pd.set_option("display.max_colwidth",80)

# %%
from SPARQLWrapper import SPARQLWrapper, JSON
import requests

# %%
sparql = SPARQLWrapper("https://query.wikidata.org/sparql")

# %%
city = year_place[-1][1]
when = int(year_place[-1][0])
print(city, when)
# Out:
# Bozen 1863

# %%
sparql.setQuery(f"""
SELECT DISTINCT
  # ?city ?cityLabel ?population ?gnd ?lat_long
WHERE {{
  # ?city wdt:P31 wd:Q1549591 .
  # ?city rdfs:label "{city}"@de .
  OPTIONAL {{ ?city wdt:P1082 ?population }}
  OPTIONAL {{ ?city wdt:P3529 ?medianIncome }}
  OPTIONAL {{ ?city wdt:P227 ?gnd }}
  OPTIONAL {{ ?city wdt:P625 ?lat_long }}
  SERVICE wikibase:label {{ bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }}
}}
""")
sparql.setReturnFormat(JSON)
results = sparql.query().convert()

# %%
results_df = pd.io.json.json_normalize(results['results']['bindings'])
results_df[['city.value', 'cityLabel.value', 'lat_long.value', 'population.value']]
# Out:
# /home/sennierer/projects/.venvs/summerschool2020-notebooks-YicCNXGB/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """Entry point for launching an IPython kernel.
#                              city.value cityLabel.value     lat_long.value population.value
# 0  http://www.wikidata.org/entity/Q6526         Bolzano  Point(11.35 46.5)           107317

# %%
import re
for idx, row in results_df.iterrows():
    print(row['lat_long.value'], type(row['lat_long.value']))
# Out:
# Point(11.35 46.5) <class 'str'>

# %%
for idx, row in results_df.iterrows():
    lat_long = re.match('Point\(([0-9\.]+)\s([0-9\.]+)\)', row['lat_long.value'])
    if lat_long:
        long = lat_long.group(1)
        lat = lat_long.group(2)
        print(lat, long)
        results_df.at[idx, 'lat'] = lat
        results_df.at[idx, 'long'] = long
# Out:
# 46.5 11.35

# %%
results_df[['city.value', 'cityLabel.value', 'lat_long.value', 'lat', 'long']]
# Out:
#                              city.value cityLabel.value     lat_long.value   lat   long
# 0  http://www.wikidata.org/entity/Q6526         Bolzano  Point(11.35 46.5)  46.5  11.35

# %%
from ipyleaflet import Map, basemaps, basemap_to_tiles, Marker, GeoJSON
watercolor = basemap_to_tiles(basemaps.Stamen.Watercolor)
center = (results_df.at[0, 'lat'], results_df.at[0, 'long'])
m = Map(layers=(watercolor, ), center=center, zoom=6)
marker = Marker(location=center, draggable=False)
m.add_layer(marker)
for idx, row in results_df.loc[1:,:].iterrows():
    center = (row['lat'], row['long'])
    marker = Marker(location=center, draggable=False)
    m.add_layer(marker)
m
# Out:
# Map(center=['46.5', '11.35'], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoo…

# %%
url = 'https://histogis.acdh-dev.oeaw.ac.at/api/where-was'
res_geo = []
for idx, row in results_df.iterrows():
    params = {'lat': row['lat'], 'lng': row['long'], 'when': str(when)}
    res = requests.get(url, params=params)
    df_geo = pd.io.json.json_normalize(res.json()['features'])
    df_geo.at[:,'wikidata'] = row['city.value']
    res_geo.append(df_geo)
# Out:
# /home/sennierer/projects/.venvs/summerschool2020-notebooks-YicCNXGB/lib/python3.6/site-packages/ipykernel_launcher.py:6: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead

# %%
res_geo[0][['@id', 'names', 'properties.adm_name', 'properties.start_date', 'properties.end_date']]
# Out:
#                                                                                @id  \
# 0  https://histogis.acdh-dev.oeaw.ac.at/shapes/permalink/7df020e1e93fe1a1b35989...
#
#                                           names properties.adm_name properties.start_date  \
# 0  [{'toponym': 'Gefürstete Grafschaft Tirol'}]     Princely County            1860-10-21
#
#   properties.end_date
# 0          1867-12-21

# %%
res_geo[0]
# Out:
#       type                                                                         bbox  \
# 0  Feature  [10.09828922682921, 45.66093004860678, 12.9660288954249, 47.74448869233967]
#
#                                           names  \
# 0  [{'toponym': 'Gefürstete Grafschaft Tirol'}]
#
#                                                                              types  \
# 0  [{'identifier': 'https://histogis.acdh-dev.oeaw.ac.at/vocabs/207', 'label': ...
#
#                     descriptions                                                     links  \
# 0  [{'value': '', 'lang': 'en'}]  [{'type': 'skos:closeMatch', 'identifier': 'Q16543832'}]
#
#                                                                                @id geometry.type  \
# 0  https://histogis.acdh-dev.oeaw.ac.at/shapes/permalink/7df020e1e93fe1a1b35989...  MultiPolygon
#
#                                                               geometry.coordinates  properties.id  \
# 0  [[[[10.49224305074131, 45.93308544114245], [10.49206013069406, 45.9417823441...          10629
#
#    ... properties.adm_name properties.start_date properties.end_date properties.date_accuracy  \
# 0  ...     Princely County            1860-10-21          1867-12-21                        D
#
#   properties.spatial_extent properties.spatial_extent_sqm  \
# 0                  3.150296                   26732.89251
#
#                                                                 properties.parents  \
# 0  [{'id': 11128, 'start_date': '1866-10-04', 'end_date': '1867-12-21', 'name':...
#
#                               properties.slugged_name  \
# 0  gefurstete-grafschaft-tirol__1860-10-21_1867-12-21
#
#                                                    when.timespans  \
# 0  [{'start': {'in': '1860-10-21'}, 'end': {'in': '1867-12-21'}}]
#
#                                wikidata
# 0  http://www.wikidata.org/entity/Q6526
#
# [1 rows x 26 columns]

# %%
res_geo[0].at[0, 'properties.id']
# Out:
# 10629

# %%
count = 0
colors = ['red', 'green', 'blue', 'yellow']
for p in res_geo[0].at[0, 'properties.parents']:
    if when > int(p['start_date'][:4]) and when < int(p['end_date'][:4]):
        geo_json = GeoJSON(
        data=requests.get(f"https://histogis.acdh-dev.oeaw.ac.at/api/tempspatial/{p['id']}/?format=json").json(),
        style={
            'opacity': 1, 'dashArray': '9', 'fillOpacity': 0.3, 'weight': 1, 'color': colors[count]
        },
        hover_style={
            'color': 'white', 'dashArray': '0', 'fillOpacity': 0.5
        },
        )
        m.add_layer(geo_json)
        count += 1
        print(f'adding: {p["name"]} / {p["start_date"]} - {p["end_date"]}')
# Out:
# adding: Österreich / 1859-10-12 - 1866-10-03

# %%
m
# Out:
# Map(bottom=5996.0, center=['46.5', '11.35'], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_…

# %%
res_geo[0].at[0, 'properties.parents']
# Out:
# [{'id': 11128,
#   'start_date': '1866-10-04',
#   'end_date': '1867-12-21',
#   'name': 'Österreich',
#   'permalink': '/shapes/permalink/51f8fe06bde59ddd2b40ff778c7b695a/'},
#  {'id': 11115,
#   'start_date': '1859-10-12',
#   'end_date': '1866-10-03',
#   'name': 'Österreich',
#   'permalink': '/shapes/permalink/95eaa76b5e732d4b2855741a42db93fb/'}]

# %% [markdown]
# ### Using Lobid/GND to pull in data on Persons (and other entities)

# %%
headers = {'accept': 'application/json'}
params = {'q': 'preferredName:Kreisky, Bruno', 'filter': 'type:Person'}
url = 'https://lobid.org/gnd/search'
res = requests.get(url, params=params, headers=headers)

# %%
res
# Out:
# <Response [200]>

# %%
res_dict = res.json()
res_df = pd.io.json.json_normalize(res_dict['member'])
# Out:
# /home/sennierer/projects/.venvs/summerschool2020-notebooks-YicCNXGB/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead

# %%
res_df[['@context', 'preferredName', 'describedBy.id', 'biographicalOrHistoricalInformation', 'dateOfBirth', 'dateOfDeath']]
# Out:
#                               @context   preferredName                         describedBy.id  \
# 0  http://lobid.org/gnd/context.jsonld  Kreisky, Bruno  https://d-nb.info/gnd/118566512/about
# 1  http://lobid.org/gnd/context.jsonld  Kreisky, Peter  https://d-nb.info/gnd/170686299/about
# 2  http://lobid.org/gnd/context.jsonld    Kreisky, Eva  https://d-nb.info/gnd/121036073/about
# 3  http://lobid.org/gnd/context.jsonld  Kreisky, Bruno  https://d-nb.info/gnd/176237682/about
#
#                                                biographicalOrHistoricalInformation   dateOfBirth  \
# 0                                [Bundeskanzler 1970-1983, Politiker, Oesterreich]  [1911-01-22]
# 1  [seit 1973 Mitarbeiter der Wirtschaftswissenschaftlichen Abteilung der Arbei...        [1944]
# 2  [Österr. Prof. für Politikwissenschaft mit Schwerpunkt politische Theorie un...  [1944-08-08]
# 3                                                                              NaN           NaN
#
#     dateOfDeath
# 0  [1990-07-29]
# 1        [2010]
# 2           NaN
# 3           NaN

# %% [markdown]
# #### Lets get some data from MPR and query Lobid for it

# %%
url_mpr = 'https://mpr.acdh.oeaw.ac.at/apis/api/entities/person/'
params_mpr = {'start_date__isnull': False}
res_mpr = requests.get(url_mpr, params=params_mpr, headers=headers)

# %%
res_dict = res_mpr.json()

# %%
res_dict
# Out:
# {'next': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/entities/person/?limit=50&offset=50&start_date__isnull=False',
#  'previous': None,
#  'count': 215,
#  'limit': 50,
#  'offset': 0,
#  'results': [{'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/entities/person/1405/',
#    'id': 1405,
#    'name': 'Ács, Karl',
#    'review': False,
#    'start_date': '1983-08-14',
#    'start_start_date': None,
#    'start_end_date': None,
#    'end_date': None,
#    'end_start_date': None,
#    'end_end_date': None,
#    'start_date_written': '14.08.1983',
#    'end_date_written': None,
#    'status': '',
#    'references': '',
#    'notes': '',
#    'published': False,
#    'first_name': None,
#    'gender': '',
#    'source': None,
#    'text': [{'id': 131,
#      'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/metainfo/text/131/',
#      'type': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/vocabularies/texttype/168/',
#      'label': 'ID: 131'}],
#    'collection': [{'id': 3,
#      'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/metainfo/collection/3/',
#      'type': None,
#      'label': 'MPR auto regest import'}],
#    'profession': [],
#    'title': []},
#   {'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/entities/person/1493/',
#    'id': 1493,
#    'name': 'Aichinger',
#    'review': False,
#    'start_date': '1805-01-01',
#    'start_start_date': None,
#    'start_end_date': None,
#    'end_date': '1864-01-01',
#    'end_start_date': None,
#    'end_end_date': None,
#    'start_date_written': '01.01.1805',
#    'end_date_written': '01.01.1864',
#    'status': 'distinct',
#    'references': None,
#    'notes': None,
#    'published': False,
#    'first_name': 'Johann',
#    'gender': '',
#    'source': None,
#    'text': [],
#    'collection': [{'id': 1,
#      'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/metainfo/collection/1/',
#      'type': None,
#      'label': 'Default import collection'}],
#    'profession': [],
#    'title': []},
#   {'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/entities/person/1495/',
#    'id': 1495,
#    'name': 'Aigner',
#    'review': False,
#    'start_date': '1818-01-18',
#    'start_start_date': None,
#    'start_end_date': None,
#    'end_date': '1886-02-18',
#    'end_start_date': None,
#    'end_end_date': None,
#    'start_date_written': '18.01.1818',
#    'end_date_written': '18.02.1886',
#    'status': 'distinct',
#    'references': None,
#    'notes': None,
#    'published': False,
#    'first_name': 'Joseph Matthäus',
#    'gender': '',
#    'source': None,
#    'text': [],
#    'collection': [{'id': 1,
#      'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/metainfo/collection/1/',
#      'type': None,
#      'label': 'Default import collection'}],
#    'profession': [],
#    'title': []},
#   {'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/entities/person/1524/',
#    'id': 1524,
#    'name': 'Albini',
#    'review': False,
#    'start_date': '1863-01-01',
#    'start_start_date': None,
#    'start_end_date': None,
#    'end_date': '1933-01-01',
#    'end_start_date': None,
#    'end_end_date': None,
#    'start_date_written': '01.01.1863',
#    'end_date_written': '01.01.1933',
#    'status': 'distinct',
#    'references': None,
#    'notes': None,
#    'published': False,
#    'first_name': 'Giuseppe',
#    'gender': '',
#    'source': None,
#    'text': [],
#    'collection': [{'id': 1,
#      'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/metainfo/collection/1/',
#      'type': None,
#      'label': 'Default import collection'}],
#    'profession': [],
#    'title': []},
#   {'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/entities/person/1562/',
#    'id': 1562,
#    'name': 'Altieri',
#    'review': False,
#    'start_date': '1805-01-01',
#    'start_start_date': None,
#    'start_end_date': None,
#    'end_date': '1867-01-01',
#    'end_start_date': None,
#    'end_end_date': None,
#    'start_date_written': '01.01.1805',
#    'end_date_written': '01.01.1867',
#    'status': 'distinct',
#    'references': None,
#    'notes': None,
#    'published': False,
#    'first_name': 'Ludovico',
#    'gender': '',
#    'source': None,
#    'text': [],
#    'collection': [{'id': 1,
#      'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/metainfo/collection/1/',
#      'type': None,
#      'label': 'Default import collection'}],
#    'profession': [],
#    'title': []},
#   {'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/entities/person/1583/',
#    'id': 1583,
#    'name': 'Amon',
#    'review': False,
#    'start_date': '1866-01-01',
#    'start_start_date': None,
#    'start_end_date': None,
#    'end_date': '1935-01-01',
#    'end_start_date': None,
#    'end_end_date': None,
#    'start_date_written': '01.01.1866',
#    'end_date_written': '01.01.1935',
#    'status': 'distinct',
#    'references': None,
#    'notes': None,
#    'published': False,
#    'first_name': 'Franz',
#    'gender': '',
#    'source': None,
#    'text': [],
#    'collection': [{'id': 1,
#      'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/metainfo/collection/1/',
#      'type': None,
#      'label': 'Default import collection'}],
#    'profession': [],
#    'title': []},
#   {'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/entities/person/1622/',
#    'id': 1622,
#    'name': 'Antonelli',
#    'review': False,
#    'start_date': '1806-04-12',
#    'start_start_date': None,
#    'start_end_date': None,
#    'end_date': '1876-11-06',
#    'end_start_date': None,
#    'end_end_date': None,
#    'start_date_written': '12.04.1806',
#    'end_date_written': '06.11.1876',
#    'status': 'distinct',
#    'references': None,
#    'notes': None,
#    'published': False,
#    'first_name': 'Giacomo',
#    'gender': '',
#    'source': None,
#    'text': [],
#    'collection': [{'id': 1,
#      'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/metainfo/collection/1/',
#      'type': None,
#      'label': 'Default import collection'}],
#    'profession': [],
#    'title': []},
#   {'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/entities/person/1820/',
#    'id': 1820,
#    'name': 'Arndts von Arnesberg',
#    'review': False,
#    'start_date': '1803-08-19',
#    'start_start_date': None,
#    'start_end_date': None,
#    'end_date': '1878-03-01',
#    'end_start_date': None,
#    'end_end_date': None,
#    'start_date_written': '19.08.1803',
#    'end_date_written': '01.03.1878',
#    'status': 'distinct',
#    'references': None,
#    'notes': None,
#    'published': False,
#    'first_name': 'Karl Ludwig',
#    'gender': '',
#    'source': None,
#    'text': [],
#    'collection': [{'id': 1,
#      'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/metainfo/collection/1/',
#      'type': None,
#      'label': 'Default import collection'}],
#    'profession': [],
#    'title': []},
#   {'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/entities/person/1825/',
#    'id': 1825,
#    'name': 'Laurentini',
#    'review': False,
#    'start_date': '1550-01-01',
#    'start_start_date': None,
#    'start_end_date': None,
#    'end_date': '1633-01-01',
#    'end_start_date': None,
#    'end_end_date': None,
#    'start_date_written': '01.01.1550',
#    'end_date_written': '01.01.1633',
#    'status': 'distinct',
#    'references': None,
#    'notes': None,
#    'published': False,
#    'first_name': 'Giovanni',
#    'gender': '',
#    'source': None,
#    'text': [],
#    'collection': [{'id': 1,
#      'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/metainfo/collection/1/',
#      'type': None,
#      'label': 'Default import collection'}],
#    'profession': [],
#    'title': []},
#   {'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/entities/person/1869/',
#    'id': 1869,
#    'name': 'Barbarigo',
#    'review': False,
#    'start_date': '1925-01-01',
#    'start_start_date': None,
#    'start_end_date': None,
#    'end_date': None,
#    'end_start_date': None,
#    'end_end_date': None,
#    'start_date_written': '01.01.1925',
#    'end_date_written': None,
#    'status': 'distinct',
#    'references': None,
#    'notes': None,
#    'published': False,
#    'first_name': 'Ida',
#    'gender': '',
#    'source': None,
#    'text': [],
#    'collection': [{'id': 1,
#      'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/metainfo/collection/1/',
#      'type': None,
#      'label': 'Default import collection'}],
#    'profession': [],
#    'title': []},
#   {'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/entities/person/2017/',
#    'id': 2017,
#    'name': 'Mühlbach',
#    'review': False,
#    'start_date': '1814-01-02',
#    'start_start_date': None,
#    'start_end_date': None,
#    'end_date': '1873-09-26',
#    'end_start_date': None,
#    'end_end_date': None,
#    'start_date_written': '02.01.1814',
#    'end_date_written': '26.09.1873',
#    'status': 'distinct',
#    'references': None,
#    'notes': None,
#    'published': False,
#    'first_name': 'Luise',
#    'gender': '',
#    'source': None,
#    'text': [],
#    'collection': [{'id': 1,
#      'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/metainfo/collection/1/',
#      'type': None,
#      'label': 'Default import collection'}],
#    'profession': [],
#    'title': []},
#   {'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/entities/person/2071/',
#    'id': 2071,
#    'name': 'Bakunin',
#    'review': False,
#    'start_date': '1814-05-30',
#    'start_start_date': None,
#    'start_end_date': None,
#    'end_date': '1876-07-01',
#    'end_start_date': None,
#    'end_end_date': None,
#    'start_date_written': '30.05.1814',
#    'end_date_written': '01.07.1876',
#    'status': 'distinct',
#    'references': None,
#    'notes': None,
#    'published': False,
#    'first_name': 'Michael Aleksandrovič',
#    'gender': '',
#    'source': None,
#    'text': [],
#    'collection': [{'id': 1,
#      'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/metainfo/collection/1/',
#      'type': None,
#      'label': 'Default import collection'}],
#    'profession': [],
#    'title': []},
#   {'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/entities/person/2075/',
#    'id': 2075,
#    'name': 'Balassa',
#    'review': False,
#    'start_date': '1731-01-01',
#    'start_start_date': None,
#    'start_end_date': None,
#    'end_date': '1807-08-28',
#    'end_start_date': None,
#    'end_end_date': None,
#    'start_date_written': '01.01.1731',
#    'end_date_written': '28.08.1807',
#    'status': 'distinct',
#    'references': None,
#    'notes': None,
#    'published': False,
#    'first_name': 'Franciscus L. B.',
#    'gender': '',
#    'source': None,
#    'text': [],
#    'collection': [{'id': 1,
#      'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/metainfo/collection/1/',
#      'type': None,
#      'label': 'Default import collection'}],
#    'profession': [],
#    'title': []},
#   {'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/entities/person/2092/',
#    'id': 2092,
#    'name': 'Loewenfeld-Russ',
#    'review': False,
#    'start_date': '1873-01-01',
#    'start_start_date': None,
#    'start_end_date': None,
#    'end_date': '1945-01-01',
#    'end_start_date': None,
#    'end_end_date': None,
#    'start_date_written': '01.01.1873',
#    'end_date_written': '01.01.1945',
#    'status': 'distinct',
#    'references': '',
#    'notes': '',
#    'published': False,
#    'first_name': 'Hans',
#    'gender': 'male',
#    'source': None,
#    'text': [],
#    'collection': [{'id': 2,
#      'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/metainfo/collection/2/',
#      'type': None,
#      'label': 'Manuell erstellte Entität'}],
#    'profession': [],
#    'title': []},
#   {'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/entities/person/2099/',
#    'id': 2099,
#    'name': 'Hussarek von Heinlein',
#    'review': False,
#    'start_date': '1865-05-03',
#    'start_start_date': None,
#    'start_end_date': None,
#    'end_date': '1935-03-06',
#    'end_start_date': None,
#    'end_end_date': None,
#    'start_date_written': '03.05.1865',
#    'end_date_written': '06.03.1935',
#    'status': 'distinct',
#    'references': '',
#    'notes': '',
#    'published': False,
#    'first_name': 'Max',
#    'gender': '',
#    'source': None,
#    'text': [],
#    'collection': [{'id': 2,
#      'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/metainfo/collection/2/',
#      'type': None,
#      'label': 'Manuell erstellte Entität'}],
#    'profession': [],
#    'title': []},
#   {'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/entities/person/2108/',
#    'id': 2108,
#    'name': 'Spitzmüller von Harmersbach',
#    'review': False,
#    'start_date': '1862-06-12',
#    'start_start_date': None,
#    'start_end_date': None,
#    'end_date': '1953-09-05',
#    'end_start_date': None,
#    'end_end_date': None,
#    'start_date_written': '12.06.1862',
#    'end_date_written': '05.09.1953',
#    'status': 'distinct',
#    'references': '',
#    'notes': '',
#    'published': False,
#    'first_name': 'Alexander',
#    'gender': '',
#    'source': None,
#    'text': [],
#    'collection': [{'id': 2,
#      'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/metainfo/collection/2/',
#      'type': None,
#      'label': 'Manuell erstellte Entität'}],
#    'profession': [],
#    'title': []},
#   {'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/entities/person/2121/',
#    'id': 2121,
#    'name': 'Schönborn',
#    'review': False,
#    'start_date': '1854-01-01',
#    'start_start_date': None,
#    'start_end_date': None,
#    'end_date': '1924-01-01',
#    'end_start_date': None,
#    'end_end_date': None,
#    'start_date_written': '01.01.1854',
#    'end_date_written': '01.01.1924',
#    'status': 'distinct',
#    'references': '',
#    'notes': '',
#    'published': False,
#    'first_name': 'Adalbert Joseph',
#    'gender': 'male',
#    'source': None,
#    'text': [],
#    'collection': [{'id': 2,
#      'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/metainfo/collection/2/',
#      'type': None,
#      'label': 'Manuell erstellte Entität'}],
#    'profession': [],
#    'title': []},
#   {'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/entities/person/2124/',
#    'id': 2124,
#    'name': 'Hold von Ferneck',
#    'review': False,
#    'start_date': '1875-10-10',
#    'start_start_date': None,
#    'start_end_date': None,
#    'end_date': '1955-01-25',
#    'end_start_date': None,
#    'end_end_date': None,
#    'start_date_written': '10.10.1875',
#    'end_date_written': '25.01.1955',
#    'status': 'distinct',
#    'references': '',
#    'notes': '',
#    'published': False,
#    'first_name': 'Alexander',
#    'gender': 'male',
#    'source': None,
#    'text': [],
#    'collection': [{'id': 1,
#      'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/metainfo/collection/1/',
#      'type': None,
#      'label': 'Default import collection'}],
#    'profession': [],
#    'title': [{'id': 47,
#      'label': 'Adelstitel >> Freiherr von',
#      'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/vocabularies/title/47/'}]},
#   {'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/entities/person/2136/',
#    'id': 2136,
#    'name': 'von Laun',
#    'review': False,
#    'start_date': '1882-01-01',
#    'start_start_date': None,
#    'start_end_date': None,
#    'end_date': '1975-01-20',
#    'end_start_date': None,
#    'end_end_date': None,
#    'start_date_written': '01.01.1882',
#    'end_date_written': '20.01.1975',
#    'status': 'distinct',
#    'references': '',
#    'notes': '',
#    'published': False,
#    'first_name': 'Rudolf',
#    'gender': 'male',
#    'source': None,
#    'text': [],
#    'collection': [{'id': 1,
#      'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/metainfo/collection/1/',
#      'type': None,
#      'label': 'Default import collection'},
#     {'id': 2,
#      'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/metainfo/collection/2/',
#      'type': None,
#      'label': 'Manuell erstellte Entität'}],
#    'profession': [],
#    'title': [{'id': 49,
#      'label': 'Adelstitel >> Edle/r von',
#      'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/vocabularies/title/49/'}]},
#   {'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/entities/person/2156/',
#    'id': 2156,
#    'name': 'von Lauda',
#    'review': False,
#    'start_date': '1859-08-05',
#    'start_start_date': None,
#    'start_end_date': None,
#    'end_date': '1932-07-03',
#    'end_start_date': None,
#    'end_end_date': None,
#    'start_date_written': '05.08.1859',
#    'end_date_written': '03.07.1932',
#    'status': 'distinct',
#    'references': '',
#    'notes': '',
#    'published': False,
#    'first_name': 'Ernst',
#    'gender': 'male',
#    'source': None,
#    'text': [],
#    'collection': [{'id': 1,
#      'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/metainfo/collection/1/',
#      'type': None,
#      'label': 'Default import collection'},
#     {'id': 2,
#      'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/metainfo/collection/2/',
#      'type': None,
#      'label': 'Manuell erstellte Entität'}],
#    'profession': [],
#    'title': [{'id': 48,
#      'label': 'Adelstitel >> Ritter von',
#      'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/vocabularies/title/48/'}]},
#   {'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/entities/person/2224/',
#    'id': 2224,
#    'name': 'Schaller',
#    'review': False,
#    'start_date': '1861-05-15',
#    'start_start_date': None,
#    'start_end_date': None,
#    'end_date': '1935-09-01',
#    'end_start_date': None,
#    'end_end_date': None,
#    'start_date_written': '1861-05-15',
#    'end_date_written': '1935-09-01',
#    'status': '',
#    'references': '',
#    'notes': 'https://books.google.at/books?id=ZWOSAwAAQBAJ&lpg=PA68&ots=WgCyXFzU4B&dq=schaller%20karl%20franz%20traumzeit&hl=de&pg=PA68#v=onepage&q=schaller%20karl%20franz%20traumzeit&f=false',
#    'published': False,
#    'first_name': 'Karl Franz',
#    'gender': 'male',
#    'source': None,
#    'text': [{'id': 1046,
#      'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/metainfo/text/1046/',
#      'type': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/vocabularies/texttype/168/',
#      'label': 'ID: 1046 - MRP 256/1918/II: Industri'}],
#    'collection': [{'id': 2,
#      'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/metainfo/collection/2/',
#      'type': None,
#      'label': 'Manuell erstellte Entität'}],
#    'profession': [],
#    'title': [{'id': 46,
#      'label': 'Adelstitel',
#      'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/vocabularies/title/46/'}]},
#   {'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/entities/person/2226/',
#    'id': 2226,
#    'name': 'Coudenhove',
#    'review': False,
#    'start_date': '1865-12-17',
#    'start_start_date': None,
#    'start_end_date': None,
#    'end_date': '1928-07-03',
#    'end_start_date': None,
#    'end_end_date': None,
#    'start_date_written': '17.12.1865',
#    'end_date_written': '03.07.1928',
#    'status': '',
#    'references': 'https://de.wikipedia.org/wiki/Max_von_Coudenhove',
#    'notes': 'gibt es eh in der GND, versehentlich angelegt, kann man das verbinden?',
#    'published': False,
#    'first_name': 'Maximilian',
#    'gender': 'male',
#    'source': None,
#    'text': [],
#    'collection': [{'id': 2,
#      'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/metainfo/collection/2/',
#      'type': None,
#      'label': 'Manuell erstellte Entität'}],
#    'profession': [],
#    'title': [{'id': 50,
#      'label': 'Adelstitel >> Graf/Gräfin von',
#      'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/vocabularies/title/50/'}]},
#   {'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/entities/person/2230/',
#    'id': 2230,
#    'name': 'Wutte',
#    'review': False,
#    'start_date': '1881-09-19',
#    'start_start_date': None,
#    'start_end_date': None,
#    'end_date': '1962-11-28',
#    'end_start_date': None,
#    'end_end_date': None,
#    'start_date_written': '19.09.1881',
#    'end_date_written': '28.11.1962',
#    'status': '',
#    'references': 'https://www.parlament.gv.at/WWER/PAD_01557/index.shtml\r\n\r\nhttps://de.wikipedia.org/wiki/Viktor_Wutte\r\n\r\nJohannes Sachslehner, 1918: die Stunden des Untergangs (Wien: Graz, 2014).\r\nhttps://books.google.at/books?id=kxNqAwAAQBAJ&pg=PT109&lpg=PT109&dq=Wirtschaftskommiss%C3%A4r+f%C3%BCr+Steiermark&source=bl&ots=XdWdAHU43n&sig=WacbDeQcSF18j_eAOK-gP_KL2SA&hl=de&sa=X&ved=0ahUKEwjrm6nT0vPbAhVDKywKHdogCXUQ6AEIRTAH#v=onepage&q=Wirtschaftskommiss%C3%A4r%20f%C3%BCr%20Steiermark&f=false',
#    'notes': 'Industrieller, Vorsitzender der Graz-Köflacher Kohle.\r\n\r\ndeutschfreiheitlicher Landesverweser im am 20. 10. 1918 gebildeten Wohlfahrtsauschuss für Steiermark, und Wirtschaftskommissär',
#    'published': False,
#    'first_name': 'Viktor',
#    'gender': 'male',
#    'source': None,
#    'text': [],
#    'collection': [{'id': 2,
#      'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/metainfo/collection/2/',
#      'type': None,
#      'label': 'Manuell erstellte Entität'}],
#    'profession': [],
#    'title': []},
#   {'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/entities/person/2247/',
#    'id': 2247,
#    'name': 'Lewyckyj',
#    'review': False,
#    'start_date': '1859-01-01',
#    'start_start_date': None,
#    'start_end_date': None,
#    'end_date': '1941-01-01',
#    'end_start_date': None,
#    'end_end_date': None,
#    'start_date_written': '1859',
#    'end_date_written': '1941',
#    'status': '',
#    'references': '',
#    'notes': '',
#    'published': False,
#    'first_name': 'Konstantin',
#    'gender': 'male',
#    'source': None,
#    'text': [],
#    'collection': [{'id': 2,
#      'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/metainfo/collection/2/',
#      'type': None,
#      'label': 'Manuell erstellte Entität'}],
#    'profession': [],
#    'title': []},
#   {'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/entities/person/2252/',
#    'id': 2252,
#    'name': 'Daszyński',
#    'review': False,
#    'start_date': '1866-10-26',
#    'start_start_date': None,
#    'start_end_date': None,
#    'end_date': '1936-10-31',
#    'end_start_date': None,
#    'end_end_date': None,
#    'start_date_written': '26.10.1866',
#    'end_date_written': '31.10.1936',
#    'status': '',
#    'references': '',
#    'notes': '',
#    'published': False,
#    'first_name': 'Ignacy',
#    'gender': 'male',
#    'source': None,
#    'text': [],
#    'collection': [{'id': 2,
#      'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/metainfo/collection/2/',
#      'type': None,
#      'label': 'Manuell erstellte Entität'}],
#    'profession': [],
#    'title': []},
#   {'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/entities/person/2254/',
#    'id': 2254,
#    'name': 'Tertil',
#    'review': False,
#    'start_date': '1864-01-01',
#    'start_start_date': None,
#    'start_end_date': None,
#    'end_date': '1925-01-01',
#    'end_start_date': None,
#    'end_end_date': None,
#    'start_date_written': '1864',
#    'end_date_written': '1925',
#    'status': '',
#    'references': '',
#    'notes': '',
#    'published': False,
#    'first_name': 'Tadeusz',
#    'gender': 'male',
#    'source': None,
#    'text': [],
#    'collection': [{'id': 2,
#      'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/metainfo/collection/2/',
#      'type': None,
#      'label': 'Manuell erstellte Entität'}],
#    'profession': [],
#    'title': []},
#   {'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/entities/person/2310/',
#    'id': 2310,
#    'name': 'Landesberger',
#    'review': False,
#    'start_date': '1865-03-04',
#    'start_start_date': None,
#    'start_end_date': None,
#    'end_date': '1920-06-21',
#    'end_start_date': None,
#    'end_end_date': None,
#    'start_date_written': '04.03.1865',
#    'end_date_written': '21.06.1920',
#    'status': 'distinct',
#    'references': '',
#    'notes': '',
#    'published': False,
#    'first_name': 'Julius',
#    'gender': 'male',
#    'source': None,
#    'text': [],
#    'collection': [{'id': 1,
#      'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/metainfo/collection/1/',
#      'type': None,
#      'label': 'Default import collection'},
#     {'id': 2,
#      'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/metainfo/collection/2/',
#      'type': None,
#      'label': 'Manuell erstellte Entität'}],
#    'profession': [],
#    'title': []},
#   {'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/entities/person/2334/',
#    'id': 2334,
#    'name': 'Reisch',
#    'review': False,
#    'start_date': '1866-04-07',
#    'start_start_date': None,
#    'start_end_date': None,
#    'end_date': '1938-12-14',
#    'end_start_date': None,
#    'end_end_date': None,
#    'start_date_written': '07.04.1866',
#    'end_date_written': '14.12.1938',
#    'status': 'distinct',
#    'references': None,
#    'notes': None,
#    'published': False,
#    'first_name': 'Richard',
#    'gender': '',
#    'source': None,
#    'text': [],
#    'collection': [{'id': 1,
#      'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/metainfo/collection/1/',
#      'type': None,
#      'label': 'Default import collection'}],
#    'profession': [],
#    'title': []},
#   {'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/entities/person/2387/',
#    'id': 2387,
#    'name': 'Heinsheimer',
#    'review': False,
#    'start_date': '1874-01-01',
#    'start_start_date': None,
#    'start_end_date': None,
#    'end_date': '1935-05-24',
#    'end_start_date': None,
#    'end_end_date': None,
#    'start_date_written': '01.01.1874',
#    'end_date_written': '24.5.1935',
#    'status': 'distinct',
#    'references': 'http://calzareth.com/tng/getperson.php?personID=I6107&tree=tree1\r\n\r\nhttp://data.onb.ac.at/rec/AC04345617\r\n\r\nhttps://wbis-1degruyter-1com-100042btb00e6.han.onb.ac.at/biographic-document/D413-854-2/images/1\r\n\r\n[S157] Werner Frank (Frank4.FTW), Compiler: Werner Frank, (about 2000), Date of Import: Feb 16, 1999.\r\n\r\n[S156] Werner Frank, Compiler: Werner Frank, (circa 2000), Date of Import: 16 Feb 1999.\r\n\r\n[S1017] Grave-Pictures, Photograph of the gravestone of Alfred and Hilda Heinsheimer in the Döbling Cemetery.\r\n\r\n[S67] Heinsheimer -Westheimer Family, 32.\r\n\r\n[S890] Neue Freie Presse, Alfred Heinsheimer obituary, 28 May 1935, p. 17.',
#    'notes': 'Generalrat der Österreichischen Nationalbank; Vizepräsident des Verbandes österreichischer Banken und Bankiers; Mitglied von Aufsichtsräten\r\nArchive:\tDeutsches Biographisches Archiv (DBA)',
#    'published': False,
#    'first_name': 'Alfred',
#    'gender': 'male',
#    'source': None,
#    'text': [],
#    'collection': [{'id': 1,
#      'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/metainfo/collection/1/',
#      'type': None,
#      'label': 'Default import collection'},
#     {'id': 2,
#      'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/metainfo/collection/2/',
#      'type': None,
#      'label': 'Manuell erstellte Entität'}],
#    'profession': [],
#    'title': []},
#   {'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/entities/person/2392/',
#    'id': 2392,
#    'name': 'Kantor',
#    'review': False,
#    'start_date': '1860-10-17',
#    'start_start_date': None,
#    'start_end_date': None,
#    'end_date': None,
#    'end_start_date': None,
#    'end_end_date': None,
#    'start_date_written': '17.10.1860',
#    'end_date_written': None,
#    'status': '',
#    'references': 'https://wbis-1degruyter-1com-100042btb00e6.han.onb.ac.at/biographic-document/D643-590-2/images/1',
#    'notes': '',
#    'published': False,
#    'first_name': 'Max',
#    'gender': 'male',
#    'source': None,
#    'text': [],
#    'collection': [{'id': 2,
#      'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/metainfo/collection/2/',
#      'type': None,
#      'label': 'Manuell erstellte Entität'}],
#    'profession': [],
#    'title': []},
#   {'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/entities/person/2449/',
#    'id': 2449,
#    'name': 'Schwarz',
#    'review': False,
#    'start_date': '1851-01-01',
#    'start_start_date': None,
#    'start_end_date': None,
#    'end_date': '1921-01-01',
#    'end_start_date': None,
#    'end_end_date': None,
#    'start_date_written': '1851',
#    'end_date_written': '1921',
#    'status': '',
#    'references': 'Kristan, Marmorek, 100, zit. n. Sandgruber, Traumzeit, 439.',
#    'notes': '',
#    'published': False,
#    'first_name': 'Julius',
#    'gender': 'male',
#    'source': None,
#    'text': [],
#    'collection': [{'id': 2,
#      'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/metainfo/collection/2/',
#      'type': None,
#      'label': 'Manuell erstellte Entität'}],
#    'profession': [],
#    'title': []},
#   {'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/entities/person/2501/',
#    'id': 2501,
#    'name': 'Frisch',
#    'review': False,
#    'start_date': '1852-01-01',
#    'start_start_date': None,
#    'start_end_date': None,
#    'end_date': None,
#    'end_start_date': None,
#    'end_end_date': None,
#    'start_date_written': '1852',
#    'end_date_written': None,
#    'status': '',
#    'references': '',
#    'notes': 'Geburtsjahr errechnet 1916-64=1852',
#    'published': False,
#    'first_name': 'Anton',
#    'gender': 'male',
#    'source': None,
#    'text': [],
#    'collection': [{'id': 2,
#      'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/metainfo/collection/2/',
#      'type': None,
#      'label': 'Manuell erstellte Entität'}],
#    'profession': [],
#    'title': []},
#   {'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/entities/person/2567/',
#    'id': 2567,
#    'name': 'Szommer',
#    'review': False,
#    'start_date': '1859-01-01',
#    'start_start_date': None,
#    'start_end_date': None,
#    'end_date': None,
#    'end_start_date': None,
#    'end_end_date': None,
#    'start_date_written': '1859',
#    'end_date_written': None,
#    'status': '',
#    'references': '',
#    'notes': '',
#    'published': False,
#    'first_name': 'Josef',
#    'gender': 'male',
#    'source': None,
#    'text': [],
#    'collection': [{'id': 2,
#      'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/metainfo/collection/2/',
#      'type': None,
#      'label': 'Manuell erstellte Entität'}],
#    'profession': [],
#    'title': []},
#   {'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/entities/person/2635/',
#    'id': 2635,
#    'name': 'Zenker',
#    'review': False,
#    'start_date': '1856-08-06',
#    'start_start_date': None,
#    'start_end_date': None,
#    'end_date': '1925-03-05',
#    'end_start_date': None,
#    'end_end_date': None,
#    'start_date_written': '06.08.1856',
#    'end_date_written': '05.03.1925',
#    'status': '',
#    'references': '; RegierungsPloetz3',
#    'notes': '',
#    'published': False,
#    'first_name': 'Franz',
#    'gender': 'male',
#    'source': None,
#    'text': [],
#    'collection': [{'id': 2,
#      'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/metainfo/collection/2/',
#      'type': None,
#      'label': 'Manuell erstellte Entität'},
#     {'id': 5,
#      'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/metainfo/collection/5/',
#      'type': None,
#      'label': 'Import Ministerlisten 12-19'},
#     {'id': 8,
#      'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/metainfo/collection/8/',
#      'type': None,
#      'label': 'importCisl'}],
#    'profession': [],
#    'title': [{'id': 47,
#      'label': 'Adelstitel >> Freiherr von',
#      'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/vocabularies/title/47/'}]},
#   {'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/entities/person/2636/',
#    'id': 2636,
#    'name': 'Morawski-Dzierżykraj',
#    'review': False,
#    'start_date': '1859-11-04',
#    'start_start_date': None,
#    'start_end_date': None,
#    'end_date': '1928-01-21',
#    'end_start_date': None,
#    'end_end_date': None,
#    'start_date_written': '04.11.1859',
#    'end_date_written': '21.01.1928',
#    'status': '',
#    'references': '; RegierungsPloetz3',
#    'notes': '',
#    'published': False,
#    'first_name': 'Zdzisław',
#    'gender': 'male',
#    'source': None,
#    'text': [],
#    'collection': [{'id': 2,
#      'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/metainfo/collection/2/',
#      'type': None,
#      'label': 'Manuell erstellte Entität'},
#     {'id': 5,
#      'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/metainfo/collection/5/',
#      'type': None,
#      'label': 'Import Ministerlisten 12-19'},
#     {'id': 8,
#      'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/metainfo/collection/8/',
#      'type': None,
#      'label': 'importCisl'}],
#    'profession': [],
#    'title': [{'id': 94,
#      'label': 'Akademischer Titel >> Dr.',
#      'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/vocabularies/title/94/'}]},
#   {'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/entities/person/2637/',
#    'id': 2637,
#    'name': 'Leth',
#    'review': False,
#    'start_date': '1861-05-27',
#    'start_start_date': None,
#    'start_end_date': None,
#    'end_date': '1930-11-17',
#    'end_start_date': None,
#    'end_end_date': None,
#    'start_date_written': '27.05.1861',
#    'end_date_written': '17.11.1930',
#    'status': 'distinct',
#    'references': '; RegierungsPloetz3',
#    'notes': '',
#    'published': False,
#    'first_name': 'Karl',
#    'gender': 'male',
#    'source': None,
#    'text': [],
#    'collection': [{'id': 1,
#      'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/metainfo/collection/1/',
#      'type': None,
#      'label': 'Default import collection'},
#     {'id': 2,
#      'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/metainfo/collection/2/',
#      'type': None,
#      'label': 'Manuell erstellte Entität'},
#     {'id': 5,
#      'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/metainfo/collection/5/',
#      'type': None,
#      'label': 'Import Ministerlisten 12-19'},
#     {'id': 8,
#      'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/metainfo/collection/8/',
#      'type': None,
#      'label': 'importCisl'}],
#    'profession': [],
#    'title': [{'id': 48,
#      'label': 'Adelstitel >> Ritter von',
#      'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/vocabularies/title/48/'},
#     {'id': 88,
#      'label': 'Auszeichnung >> geheimer Rat',
#      'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/vocabularies/title/88/'},
#     {'id': 94,
#      'label': 'Akademischer Titel >> Dr.',
#      'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/vocabularies/title/94/'}]},
#   {'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/entities/person/2645/',
#    'id': 2645,
#    'name': 'Löw',
#    'review': False,
#    'start_date': '1876-01-01',
#    'start_start_date': None,
#    'start_end_date': None,
#    'end_date': None,
#    'end_start_date': None,
#    'end_end_date': None,
#    'start_date_written': '1876',
#    'end_date_written': None,
#    'status': '',
#    'references': '',
#    'notes': '',
#    'published': False,
#    'first_name': 'Rudolf',
#    'gender': 'male',
#    'source': None,
#    'text': [],
#    'collection': [{'id': 2,
#      'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/metainfo/collection/2/',
#      'type': None,
#      'label': 'Manuell erstellte Entität'}],
#    'profession': [],
#    'title': []},
#   {'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/entities/person/2663/',
#    'id': 2663,
#    'name': 'Weigl',
#    'review': False,
#    'start_date': '1873-01-01',
#    'start_start_date': None,
#    'start_end_date': None,
#    'end_date': None,
#    'end_start_date': None,
#    'end_end_date': None,
#    'start_date_written': '1873',
#    'end_date_written': None,
#    'status': '',
#    'references': '',
#    'notes': '',
#    'published': False,
#    'first_name': 'Heinrich',
#    'gender': 'male',
#    'source': None,
#    'text': [],
#    'collection': [{'id': 2,
#      'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/metainfo/collection/2/',
#      'type': None,
#      'label': 'Manuell erstellte Entität'}],
#    'profession': [],
#    'title': [{'id': 94,
#      'label': 'Akademischer Titel >> Dr.',
#      'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/vocabularies/title/94/'}]},
#   {'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/entities/person/2673/',
#    'id': 2673,
#    'name': 'Görig',
#    'review': False,
#    'start_date': '1856-01-01',
#    'start_start_date': None,
#    'start_end_date': None,
#    'end_date': None,
#    'end_start_date': None,
#    'end_end_date': None,
#    'start_date_written': '1856',
#    'end_date_written': None,
#    'status': '',
#    'references': '',
#    'notes': '',
#    'published': False,
#    'first_name': 'Ernst',
#    'gender': 'male',
#    'source': None,
#    'text': [],
#    'collection': [{'id': 2,
#      'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/metainfo/collection/2/',
#      'type': None,
#      'label': 'Manuell erstellte Entität'}],
#    'profession': [],
#    'title': []},
#   {'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/entities/person/2683/',
#    'id': 2683,
#    'name': 'Mach',
#    'review': False,
#    'start_date': '1858-01-01',
#    'start_start_date': None,
#    'start_end_date': None,
#    'end_date': None,
#    'end_start_date': None,
#    'end_end_date': None,
#    'start_date_written': '1858',
#    'end_date_written': None,
#    'status': '',
#    'references': '',
#    'notes': '',
#    'published': False,
#    'first_name': 'Emil',
#    'gender': 'male',
#    'source': None,
#    'text': [],
#    'collection': [{'id': 2,
#      'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/metainfo/collection/2/',
#      'type': None,
#      'label': 'Manuell erstellte Entität'}],
#    'profession': [],
#    'title': []},
#   {'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/entities/person/2708/',
#    'id': 2708,
#    'name': 'Gałecki',
#    'review': False,
#    'start_date': '1864-01-01',
#    'start_start_date': None,
#    'start_end_date': None,
#    'end_date': None,
#    'end_start_date': None,
#    'end_end_date': None,
#    'start_date_written': '1864',
#    'end_date_written': None,
#    'status': '',
#    'references': '',
#    'notes': '',
#    'published': False,
#    'first_name': 'Kasimir',
#    'gender': 'male',
#    'source': None,
#    'text': [],
#    'collection': [{'id': 2,
#      'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/metainfo/collection/2/',
#      'type': None,
#      'label': 'Manuell erstellte Entität'}],
#    'profession': [],
#    'title': []},
#   {'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/entities/person/2742/',
#    'id': 2742,
#    'name': 'Widmann',
#    'review': False,
#    'start_date': '1868-05-20',
#    'start_start_date': None,
#    'start_end_date': None,
#    'end_date': None,
#    'end_start_date': None,
#    'end_end_date': None,
#    'start_date_written': '20.05.1868',
#    'end_date_written': None,
#    'status': '',
#    'references': '; RegierungsPloetz3; RegierungsPloetz3',
#    'notes': '',
#    'published': False,
#    'first_name': 'Adalbert',
#    'gender': 'male',
#    'source': None,
#    'text': [],
#    'collection': [{'id': 2,
#      'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/metainfo/collection/2/',
#      'type': None,
#      'label': 'Manuell erstellte Entität'},
#     {'id': 5,
#      'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/metainfo/collection/5/',
#      'type': None,
#      'label': 'Import Ministerlisten 12-19'},
#     {'id': 8,
#      'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/metainfo/collection/8/',
#      'type': None,
#      'label': 'importCisl'}],
#    'profession': [],
#    'title': [{'id': 47,
#      'label': 'Adelstitel >> Freiherr von',
#      'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/vocabularies/title/47/'}]},
#   {'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/entities/person/2763/',
#    'id': 2763,
#    'name': 'Czartoryski',
#    'review': False,
#    'start_date': '1864-02-10',
#    'start_start_date': None,
#    'start_end_date': None,
#    'end_date': '1945-09-06',
#    'end_start_date': None,
#    'end_end_date': None,
#    'start_date_written': '10.02.1864',
#    'end_date_written': '06.09.1945',
#    'status': '',
#    'references': '',
#    'notes': '',
#    'published': False,
#    'first_name': 'Witold Leon',
#    'gender': 'male',
#    'source': None,
#    'text': [],
#    'collection': [{'id': 2,
#      'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/metainfo/collection/2/',
#      'type': None,
#      'label': 'Manuell erstellte Entität'}],
#    'profession': [],
#    'title': [{'id': 51,
#      'label': 'Adelstitel >> Fürst/in von',
#      'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/vocabularies/title/51/'}]},
#   {'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/entities/person/2784/',
#    'id': 2784,
#    'name': 'Zborowski-Kostrakiewicz',
#    'review': False,
#    'start_date': '1860-08-30',
#    'start_start_date': None,
#    'start_end_date': None,
#    'end_date': '1928-10-27',
#    'end_start_date': None,
#    'end_end_date': None,
#    'start_date_written': '30.08.1860',
#    'end_date_written': '27.10.1928',
#    'status': '',
#    'references': 'https://www.geni.com/people/Wlodzimierz-Kostrakiewicz-Zborowski/6000000018559178124\r\n\r\nund staatshandbuch',
#    'notes': '',
#    'published': False,
#    'first_name': 'Wladimir',
#    'gender': 'male',
#    'source': None,
#    'text': [],
#    'collection': [{'id': 2,
#      'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/metainfo/collection/2/',
#      'type': None,
#      'label': 'Manuell erstellte Entität'}],
#    'profession': [],
#    'title': [{'id': 48,
#      'label': 'Adelstitel >> Ritter von',
#      'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/vocabularies/title/48/'}]},
#   {'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/entities/person/2791/',
#    'id': 2791,
#    'name': 'von Fesch',
#    'review': False,
#    'start_date': '1861-01-01',
#    'start_start_date': None,
#    'start_end_date': None,
#    'end_date': '1939-01-01',
#    'end_start_date': None,
#    'end_end_date': None,
#    'start_date_written': '1861',
#    'end_date_written': '1939',
#    'status': '',
#    'references': 'https://www.rizes.cloud/index.php/en/style-your-website',
#    'notes': '',
#    'published': False,
#    'first_name': 'Emil Milosch',
#    'gender': 'male',
#    'source': None,
#    'text': [],
#    'collection': [{'id': 2,
#      'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/metainfo/collection/2/',
#      'type': None,
#      'label': 'Manuell erstellte Entität'}],
#    'profession': [],
#    'title': []},
#   {'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/entities/person/2808/',
#    'id': 2808,
#    'name': 'Ezdorf',
#    'review': False,
#    'start_date': '1879-02-14',
#    'start_start_date': None,
#    'start_end_date': None,
#    'end_date': '1950-12-12',
#    'end_start_date': None,
#    'end_end_date': None,
#    'start_date_written': '14.02.1879',
#    'end_date_written': '12.12.1950',
#    'status': '',
#    'references': '',
#    'notes': '',
#    'published': False,
#    'first_name': 'Josef Rudolph',
#    'gender': 'male',
#    'source': None,
#    'text': [],
#    'collection': [{'id': 2,
#      'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/metainfo/collection/2/',
#      'type': None,
#      'label': 'Manuell erstellte Entität'}],
#    'profession': [],
#    'title': [{'id': 50,
#      'label': 'Adelstitel >> Graf/Gräfin von',
#      'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/vocabularies/title/50/'}]},
#   {'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/entities/person/2817/',
#    'id': 2817,
#    'name': 'Ezdorf',
#    'review': False,
#    'start_date': '1846-01-01',
#    'start_start_date': None,
#    'start_end_date': None,
#    'end_date': None,
#    'end_start_date': None,
#    'end_end_date': None,
#    'start_date_written': '1846',
#    'end_date_written': None,
#    'status': '',
#    'references': '',
#    'notes': '',
#    'published': False,
#    'first_name': 'Josef Ferdinand',
#    'gender': 'male',
#    'source': None,
#    'text': [],
#    'collection': [{'id': 2,
#      'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/metainfo/collection/2/',
#      'type': None,
#      'label': 'Manuell erstellte Entität'}],
#    'profession': [],
#    'title': [{'id': 50,
#      'label': 'Adelstitel >> Graf/Gräfin von',
#      'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/vocabularies/title/50/'}]},
#   {'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/entities/person/2841/',
#    'id': 2841,
#    'name': 'Schwegel',
#    'review': False,
#    'start_date': '1875-02-17',
#    'start_start_date': None,
#    'start_end_date': None,
#    'end_date': '1962-02-05',
#    'end_start_date': None,
#    'end_end_date': None,
#    'start_date_written': '17.02.1875',
#    'end_date_written': '05.02.1962',
#    'status': '',
#    'references': 'Švegel, Ivan Krizostom (1875–1962). Slovenska biografija. Slovenska akademija znanosti in umetnosti, Znanstvenoraziskovalni center SAZU, 2013. http://www.slovenska-biografija.si/oseba/sbi680577/#slovenski-biografski-leksikon (10. december 2018). Izvirna objava v: Slovenski biografski leksikon: 11. zv. Stelè - Švikaršič. Alfonz Gspan et al. Ljubljana, Slovenska akademija znanosti in umetnosti, 1971.',
#    'notes': '',
#    'published': False,
#    'first_name': 'Ivan Krizostom',
#    'gender': 'male',
#    'source': None,
#    'text': [],
#    'collection': [{'id': 2,
#      'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/metainfo/collection/2/',
#      'type': None,
#      'label': 'Manuell erstellte Entität'}],
#    'profession': [],
#    'title': []},
#   {'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/entities/person/2842/',
#    'id': 2842,
#    'name': 'Taaffe',
#    'review': False,
#    'start_date': '1866-01-01',
#    'start_start_date': None,
#    'start_end_date': None,
#    'end_date': '1928-01-01',
#    'end_start_date': None,
#    'end_end_date': None,
#    'start_date_written': '01.01.1866',
#    'end_date_written': '01.01.1928',
#    'status': 'distinct',
#    'references': None,
#    'notes': None,
#    'published': False,
#    'first_name': 'Marie Amalia',
#    'gender': '',
#    'source': None,
#    'text': [],
#    'collection': [{'id': 1,
#      'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/metainfo/collection/1/',
#      'type': None,
#      'label': 'Default import collection'}],
#    'profession': [],
#    'title': []},
#   {'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/entities/person/2848/',
#    'id': 2848,
#    'name': 'Coudenhove',
#    'review': False,
#    'start_date': '1890-11-02',
#    'start_start_date': None,
#    'start_end_date': None,
#    'end_date': '1964-01-01',
#    'end_start_date': None,
#    'end_end_date': None,
#    'start_date_written': '02.11.1890',
#    'end_date_written': '1964',
#    'status': 'distinct',
#    'references': '',
#    'notes': '',
#    'published': False,
#    'first_name': 'Eduard Franz',
#    'gender': 'male',
#    'source': None,
#    'text': [],
#    'collection': [{'id': 1,
#      'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/metainfo/collection/1/',
#      'type': None,
#      'label': 'Default import collection'},
#     {'id': 2,
#      'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/metainfo/collection/2/',
#      'type': None,
#      'label': 'Manuell erstellte Entität'}],
#    'profession': [],
#    'title': [{'id': 50,
#      'label': 'Adelstitel >> Graf/Gräfin von',
#      'url': 'http://mpr.sisyphos.arz.oeaw.ac.at/apis/api/vocabularies/title/50/'}]}]}

# %%
for r in res_dict['results']:
    params = {'q': f"preferredName:{r['name']} OR preferredName:{r['name']}, {r['first_name']} AND dateOfBirth:{r['start_date']}", "filter": "type:Person"}
    res = requests.get(url, params=params, headers=headers)
    res_dict_1 = res.json()
    if int(res_dict_1['totalItems']) > 0:
        print(f"name: {r['name']}, {r['first_name']}, GND results: #{res_dict_1['totalItems']}, GND ID: {res_dict_1['member'][0]['id']}, MPR: https://mpr.acdh.oeaw.ac.at/apis/entities/entity/person/{r['id']}/detail")
    else:
        print(f"name: {r['name']}, {r['first_name']}, GND results: #{res_dict_1['totalItems']}")
# Out:
# name: Ács, Karl, None, GND results: #0
# name: Aichinger, Johann, GND results: #0
# name: Aigner, Joseph Matthäus, GND results: #1, GND ID: https://d-nb.info/gnd/116274344, MPR: https://mpr.acdh.oeaw.ac.at/apis/entities/entity/person/1495/detail
# name: Albini, Giuseppe, GND results: #0
# name: Altieri, Ludovico, GND results: #0
# name: Amon, Franz, GND results: #1, GND ID: https://d-nb.info/gnd/117471437, MPR: https://mpr.acdh.oeaw.ac.at/apis/entities/entity/person/1583/detail
# name: Antonelli, Giacomo, GND results: #0
# name: Arndts von Arnesberg, Karl Ludwig, GND results: #1, GND ID: https://d-nb.info/gnd/100416993, MPR: https://mpr.acdh.oeaw.ac.at/apis/entities/entity/person/1820/detail
# name: Laurentini, Giovanni, GND results: #0
# name: Barbarigo, Ida, GND results: #0
# name: Mühlbach, Luise, GND results: #1, GND ID: https://d-nb.info/gnd/118585754, MPR: https://mpr.acdh.oeaw.ac.at/apis/entities/entity/person/2017/detail
# name: Bakunin, Michael Aleksandrovič, GND results: #1, GND ID: https://d-nb.info/gnd/118506102, MPR: https://mpr.acdh.oeaw.ac.at/apis/entities/entity/person/2071/detail
# name: Balassa, Franciscus L. B., GND results: #0
# name: Loewenfeld-Russ, Hans, GND results: #1, GND ID: https://d-nb.info/gnd/117149853, MPR: https://mpr.acdh.oeaw.ac.at/apis/entities/entity/person/2092/detail
# name: Hussarek von Heinlein, Max, GND results: #1, GND ID: https://d-nb.info/gnd/118910930, MPR: https://mpr.acdh.oeaw.ac.at/apis/entities/entity/person/2099/detail
# name: Spitzmüller von Harmersbach, Alexander, GND results: #0
# name: Schönborn, Adalbert Joseph, GND results: #0
# name: Hold von Ferneck, Alexander, GND results: #1, GND ID: https://d-nb.info/gnd/116960159, MPR: https://mpr.acdh.oeaw.ac.at/apis/entities/entity/person/2124/detail
# name: von Laun, Rudolf, GND results: #0
# name: von Lauda, Ernst, GND results: #1, GND ID: https://d-nb.info/gnd/1070957348, MPR: https://mpr.acdh.oeaw.ac.at/apis/entities/entity/person/2156/detail
# name: Schaller, Karl Franz, GND results: #0
# name: Coudenhove, Maximilian, GND results: #0
# name: Wutte, Viktor, GND results: #0
# name: Lewyckyj, Konstantin, GND results: #0
# name: Daszyński, Ignacy, GND results: #1, GND ID: https://d-nb.info/gnd/118934481, MPR: https://mpr.acdh.oeaw.ac.at/apis/entities/entity/person/2252/detail
# name: Tertil, Tadeusz, GND results: #0
# name: Landesberger, Julius, GND results: #1, GND ID: https://d-nb.info/gnd/136170862, MPR: https://mpr.acdh.oeaw.ac.at/apis/entities/entity/person/2310/detail
# name: Reisch, Richard, GND results: #1, GND ID: https://d-nb.info/gnd/100859666, MPR: https://mpr.acdh.oeaw.ac.at/apis/entities/entity/person/2334/detail
# name: Heinsheimer, Alfred, GND results: #0
# name: Kantor, Max, GND results: #0
# name: Schwarz, Julius, GND results: #1, GND ID: https://d-nb.info/gnd/1014362873, MPR: https://mpr.acdh.oeaw.ac.at/apis/entities/entity/person/2449/detail
# name: Frisch, Anton, GND results: #0
# name: Szommer, Josef, GND results: #1, GND ID: https://d-nb.info/gnd/1053642199, MPR: https://mpr.acdh.oeaw.ac.at/apis/entities/entity/person/2567/detail
# name: Zenker, Franz, GND results: #0
# name: Morawski-Dzierżykraj, Zdzisław, GND results: #0
# name: Leth, Karl, GND results: #0
# name: Löw, Rudolf, GND results: #1, GND ID: https://d-nb.info/gnd/13010972X, MPR: https://mpr.acdh.oeaw.ac.at/apis/entities/entity/person/2645/detail
# name: Weigl, Heinrich, GND results: #2, GND ID: https://d-nb.info/gnd/116423056, MPR: https://mpr.acdh.oeaw.ac.at/apis/entities/entity/person/2663/detail
# name: Görig, Ernst, GND results: #0
# name: Mach, Emil, GND results: #0
# name: Gałecki, Kasimir, GND results: #0
# name: Widmann, Adalbert, GND results: #0
# name: Czartoryski, Witold Leon, GND results: #0
# name: Zborowski-Kostrakiewicz, Wladimir, GND results: #0
# name: von Fesch, Emil Milosch, GND results: #0
# name: Ezdorf, Josef Rudolph, GND results: #0
# name: Ezdorf, Josef Ferdinand, GND results: #0
# name: Schwegel, Ivan Krizostom, GND results: #1, GND ID: https://d-nb.info/gnd/1193660173, MPR: https://mpr.acdh.oeaw.ac.at/apis/entities/entity/person/2841/detail
# name: Taaffe, Marie Amalia, GND results: #0
# name: Coudenhove, Eduard Franz, GND results: #0
